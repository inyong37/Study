# %%
# -*- coding: utf-8 -*-
# Author: Inyong Hwang (inyong1020@gmail.com)
# Date: 2019-06-17-Mon
# Korean Character STR 32*32 by ResNet epoch=1~100

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
print('=====Google Drive=====')
# !ls '/content/drive/My Drive/'
print('=====input=====')
# !ls '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/PKL_32v4/'
# Out:
# =====Google Drive=====
#  논문			      'Colab Notebooks'   Lab-Desktop   PUBLIC
# 'AI 사물인식 해커톤 (2).zip'   Dataset		  Program       USB
# =====input=====
# images.pkl  labels.pkl

# %%
# read directory
import sys
import os
import pickle
import numpy as np
from keras.utils import to_categorical
from collections import Counter
from sklearn.model_selection import train_test_split
from keras import layers
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2
from keras.models import Model
from keras import backend as k
import matplotlib.pyplot as plt
import pandas as pd

model_name = 'resnet56v2_1_100_32'
input_dir = '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/PKL_32v4/'
output_dir = '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/'

if os.path.isdir(output_dir):
    pass
else:
    os.mkdir(output_dir)

if os.path.isdir(output_dir + str(model_name)):
    pass
else:
    os.mkdir(output_dir + str(model_name))
   
filenames = os.listdir(input_dir)
for filename in filenames:
    if 'image' in filename:
        print('loading %s' % filename)
        with open(input_dir + filename, 'rb') as f:
            X = pickle.load(f)
        print('loaded!')
    else:
        print('loading %s' % filename)
        with open(input_dir + filename, 'rb') as f:
            Y = pickle.load(f)
        print('loaded!')

X = np.array(X)
X = X[:, :, :, np.newaxis]
input_shape = X.shape[1:]
Y = np.array(Y)
num_classes = len(Counter(Y))
Y = to_categorical(Y, num_classes)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=37, shuffle=True)
print('# of images: %d' % len(X))
print('Shape of images:', X.shape[1:])
print('# of train set: %d' % len(X_train), '# of test set: %d' % len(X_test))
del X, Y

# Define Model
version = 2
n = 6
depth = n * 9 + 2
batch_size = 128
epochs = 100 # 200
model_type = 'ResNet%dv%d' % (depth, version)


def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(filters=filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v2(input_shape=input_shape, depth=depth, classes=num_classes):
    filters_in = 16
    resnet_blocks = int((depth - 2) / 9)

    i = Input(shape=input_shape, name='Input_Image')
    x = resnet_layer(inputs=i, filters=filters_in, conv_first=True)
    for stage in range(3):
        for resnet_block in range(resnet_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                filters_out = filters_in * 4
                if resnet_block == 0:
                    activation = None
                    batch_normalization = False
            else:
                filters_out = filters_in * 2
                if resnet_block == 0:
                    strides = 2
            y = resnet_layer(inputs=x, filters=filters_in, kernel_size=1, strides=strides, activation=activation, batch_normalization=batch_normalization, conv_first=False)
            y = resnet_layer(inputs=y, filters=filters_in, conv_first=False)
            y = resnet_layer(inputs=y, filters=filters_out, kernel_size=1, conv_first=False)
            if resnet_block == 0:
                x = resnet_layer(inputs=x, filters=filters_out, kernel_size=1, strides=strides, activation=None, batch_normalization=False)
            x = layers.add([x, y])
        filters_in = filters_out

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # x = AveragePooling2D(pool_size=8)(x)
    x = Flatten()(x)
    y = Dense(classes, activation='softmax', kernel_initializer='he_normal')(x)
    model = Model(inputs=i, outputs=y)
    return model


model = resnet_v2(input_shape=input_shape, depth=depth)
model.summary()
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=lr_schedule(0)), metrics=['accuracy'])
print(model_type)
checkpoint = ModelCheckpoint(filepath=output_dir + str(model_name) + '/checkpoint.{epoch:03d}.hg',
                             monitor='val_acc',
                             verbose=2,
                             save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]
fit = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=2, callbacks=callbacks, validation_split=0.2, initial_epoch=0)
eva = model.evaluate(X_test, Y_test, verbose=2)


def plot_loss(history, output_dir, model_name):
    plt.clf()
    plt_loss = plt
    plt_loss.plot(history.history['loss'])
    plt_loss.plot(history.history['val_loss'])
    plt_loss.title('Model Loss')
    plt_loss.xlabel('Epoch')
    plt_loss.ylabel('Loss')
    plt_loss.legend(['Train', 'Test'], loc=0)
    figure = output_dir + str(model_name) + '/loss.png'
    plt_loss.savefig(figure, dpi=1080)


def plot_acc(history, output_dir, model_name):
    plt.clf()
    plt_acc = plt
    plt_acc.plot(history.history['acc'])
    plt_acc.plot(history.history['val_acc'])
    plt_acc.title('Model Accuracy')
    plt_acc.xlabel('Epoch')
    plt_acc.ylabel('Accuracy')
    plt_acc.legend(['Train', 'Test'], loc=0)
    figure = output_dir + str(model_name) + '/accuracy.png'
    plt_acc.savefig(figure, dpi=1080)


def csv_fit(history, output_dir, model_name):
    train_data = pd.DataFrame(history.history)
    train_data.to_csv(output_dir + str(model_name) + '/csv_fit.csv')
    return None


def csv_eva(history, output_dir, model_name):
    test_data = pd.DataFrame(history)
    test_data = test_data.T
    if len(history) == 5:
        test_data_header = ['test_loss', 'test_acc', 'precision', 'recall', 'f1score']
    else:
        test_data_header = ['test_loss', 'test_acc']
    test_data.to_csv(output_dir + str(model_name) + '/csv_eva.csv', header=test_data_header)
    return None


print('Model: ', model_name, ', Loss: ', eva[0], ', Accuracy: ', eva[1])
plot_loss(history=fit, output_dir=output_dir, model_name=model_name)
plot_acc(history=fit, output_dir=output_dir, model_name=model_name)
csv_fit(history=fit, output_dir=output_dir, model_name=model_name)
csv_eva(history=eva, output_dir=output_dir, model_name=model_name)
model.save(output_dir + str(model_name) + '/model.h5')
model_json = model.to_json()
with open(output_dir + str(model_name) + '/model.json', 'w') as json_file:
    json_file.write(model_json)
    json_file.close()
model_yaml = model.to_yaml()
with open(output_dir + str(model_name) + '/model.yaml', 'w') as yaml_file:
    yaml_file.write(model_yaml)
    yaml_file.close()
model.save_weights(output_dir + str(model_name) + '/weights.h5')
print('Done!')
# Out:
# Using TensorFlow backend.
# loading labels.pkl
# loaded!
# loading images.pkl
# loaded!
# WARNING: Logging before flag parsing goes to stderr.
# W0617 05:16:19.587194 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0617 05:16:19.624021 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0617 05:16:19.625961 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0617 05:16:19.670857 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0617 05:16:19.671809 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# # of images: 139104
# Shape of images: (32, 32, 1)
# # of train set: 111283 # of test set: 27821
# W0617 05:16:22.021548 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0617 05:16:27.126002 139742434822016 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input_Image (InputLayer)        (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   160         Input_Image[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 16)   1040        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 16)   2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 16)   64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 16)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   1088        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 64)   0           add_3[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   1040        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 16)   2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 16)   64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 64)   1088        activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 64)   0           add_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 16)   1040        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 16)   64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 16)   2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 16)   64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 64)   1088        activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 64)   0           add_5[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 64)   4160        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   36928       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 128)  8320        add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 128)  8320        activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 128)  0           conv2d_24[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 64)   8256        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 64)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  8320        activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 128)  0           add_7[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 64)   8256        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 64)   36928       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  8320        activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 128)  0           add_8[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 128)  512         add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   8256        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 64)   36928       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 128)  8320        activation_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 128)  0           add_9[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 128)  512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 64)   8256        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 128)  8320        activation_33[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 128)  0           add_10[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 64)   8256        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 16, 64)   36928       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 64)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 128)  8320        activation_36[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 128)  0           add_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16, 16, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    16512       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 128)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 128)    147584      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 128)    512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 128)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 256)    33024       add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 256)    33024       activation_39[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 256)    0           conv2d_43[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 256)    1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 256)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    32896       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 128)    512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 128)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    147584      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 128)    512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 128)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 256)    33024       activation_42[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 256)    0           add_13[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 256)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    32896       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    147584      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 128)    512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 128)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 256)    33024       activation_45[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 256)    0           add_14[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 256)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 128)    32896       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8, 8, 128)    512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 128)    147584      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 8, 8, 128)    512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 256)    33024       activation_48[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           add_15[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 8, 256)    1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 256)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 128)    32896       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 8, 128)    512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 128)    147584      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 128)    512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 256)    33024       activation_51[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           add_16[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 256)    1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 128)    32896       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 128)    512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 128)    147584      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 128)    512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 256)    33024       activation_54[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           add_17[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 256)    1024        add_18[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 256)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16384)        0           activation_55[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1008)         16516080    flatten_1[0][0]
# ==================================================================================================
# Total params: 18,186,960
# Trainable params: 18,176,560
# Non-trainable params: 10,400
# __________________________________________________________________________________________________
# Learning rate:  0.001
# ResNet56v2
# W0617 05:16:28.173705 139742434822016 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 89026 samples, validate on 22257 samples
# Epoch 1/100
# Learning rate:  0.001
#  - 138s - loss: 3.9668 - acc: 0.4976 - val_loss: 1.4768 - val_acc: 0.8190
#
# Epoch 00001: val_acc improved from -inf to 0.81898, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.001.hg
# Epoch 2/100
# Learning rate:  0.001
#  - 121s - loss: 1.6139 - acc: 0.8368 - val_loss: 1.4220 - val_acc: 0.8700
#
# Epoch 00002: val_acc improved from 0.81898 to 0.87002, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.002.hg
# Epoch 3/100
# Learning rate:  0.001
#  - 121s - loss: 1.1873 - acc: 0.9169 - val_loss: 1.0630 - val_acc: 0.9105
#
# Epoch 00003: val_acc improved from 0.87002 to 0.91050, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.003.hg
# Epoch 4/100
# Learning rate:  0.001
#  - 121s - loss: 0.9436 - acc: 0.9471 - val_loss: 0.9788 - val_acc: 0.9124
#
# Epoch 00004: val_acc improved from 0.91050 to 0.91243, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.004.hg
# Epoch 5/100
# Learning rate:  0.001
#  - 121s - loss: 0.6902 - acc: 0.9742 - val_loss: 0.7895 - val_acc: 0.9389
#
# Epoch 00005: val_acc improved from 0.91243 to 0.93894, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.005.hg
# Epoch 6/100
# Learning rate:  0.001
#  - 121s - loss: 0.5717 - acc: 0.9838 - val_loss: 0.7328 - val_acc: 0.9340
#
# Epoch 00006: val_acc did not improve from 0.93894
# Epoch 7/100
# Learning rate:  0.001
#  - 122s - loss: 0.5006 - acc: 0.9826 - val_loss: 0.7201 - val_acc: 0.9293
#
# Epoch 00007: val_acc did not improve from 0.93894
# Epoch 8/100
# Learning rate:  0.001
#  - 121s - loss: 0.4408 - acc: 0.9821 - val_loss: 0.6711 - val_acc: 0.9210
#
# Epoch 00008: val_acc did not improve from 0.93894
# Epoch 9/100
# Learning rate:  0.001
#  - 121s - loss: 0.3837 - acc: 0.9838 - val_loss: 0.6183 - val_acc: 0.9216
#
# Epoch 00009: val_acc did not improve from 0.93894
# Epoch 10/100
# Learning rate:  0.001
#  - 121s - loss: 0.3350 - acc: 0.9851 - val_loss: 0.5539 - val_acc: 0.9318
#
# Epoch 00010: val_acc did not improve from 0.93894
# Epoch 11/100
# Learning rate:  0.001
#  - 121s - loss: 0.2848 - acc: 0.9882 - val_loss: 0.4969 - val_acc: 0.9381
#
# Epoch 00011: val_acc did not improve from 0.93894
# Epoch 12/100
# Learning rate:  0.001
#  - 121s - loss: 0.2625 - acc: 0.9858 - val_loss: 0.5875 - val_acc: 0.9146
#
# Epoch 00012: val_acc did not improve from 0.93894
# Epoch 13/100
# Learning rate:  0.001
#  - 121s - loss: 0.2253 - acc: 0.9896 - val_loss: 0.4316 - val_acc: 0.9387
#
# Epoch 00013: val_acc did not improve from 0.93894
# Epoch 14/100
# Learning rate:  0.001
#  - 121s - loss: 0.2022 - acc: 0.9897 - val_loss: 0.5671 - val_acc: 0.9131
#
# Epoch 00014: val_acc did not improve from 0.93894
# Epoch 15/100
# Learning rate:  0.001
#  - 121s - loss: 0.1849 - acc: 0.9900 - val_loss: 0.6542 - val_acc: 0.8875
#
# Epoch 00015: val_acc did not improve from 0.93894
# Epoch 16/100
# Learning rate:  0.001
#  - 120s - loss: 0.1730 - acc: 0.9896 - val_loss: 0.8508 - val_acc: 0.8579
#
# Epoch 00016: val_acc did not improve from 0.93894
# Epoch 17/100
# Learning rate:  0.001
#  - 121s - loss: 0.1537 - acc: 0.9917 - val_loss: 0.4036 - val_acc: 0.9378
#
# Epoch 00017: val_acc did not improve from 0.93894
# Epoch 18/100
# Learning rate:  0.001
#  - 120s - loss: 0.1437 - acc: 0.9917 - val_loss: 0.3801 - val_acc: 0.9419
#
# Epoch 00018: val_acc improved from 0.93894 to 0.94191, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.018.hg
# Epoch 19/100
# Learning rate:  0.001
#  - 121s - loss: 0.1333 - acc: 0.9923 - val_loss: 0.3524 - val_acc: 0.9445
#
# Epoch 00019: val_acc improved from 0.94191 to 0.94447, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.019.hg
# Epoch 20/100
# Learning rate:  0.001
#  - 121s - loss: 0.1216 - acc: 0.9934 - val_loss: 0.4297 - val_acc: 0.9294
#
# Epoch 00020: val_acc did not improve from 0.94447
# Epoch 21/100
# Learning rate:  0.001
#  - 120s - loss: 0.1130 - acc: 0.9936 - val_loss: 0.3518 - val_acc: 0.9406
#
# Epoch 00021: val_acc did not improve from 0.94447
# Epoch 22/100
# Learning rate:  0.001
#  - 120s - loss: 0.1044 - acc: 0.9941 - val_loss: 0.3346 - val_acc: 0.9456
#
# Epoch 00022: val_acc improved from 0.94447 to 0.94564, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.022.hg
# Epoch 23/100
# Learning rate:  0.001
#  - 120s - loss: 0.1009 - acc: 0.9938 - val_loss: 0.3038 - val_acc: 0.9491
#
# Epoch 00023: val_acc improved from 0.94564 to 0.94909, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.023.hg
# Epoch 24/100
# Learning rate:  0.001
#  - 120s - loss: 0.0924 - acc: 0.9948 - val_loss: 0.9605 - val_acc: 0.8422
#
# Epoch 00024: val_acc did not improve from 0.94909
# Epoch 25/100
# Learning rate:  0.001
#  - 119s - loss: 0.0955 - acc: 0.9931 - val_loss: 0.5773 - val_acc: 0.9030
#
# Epoch 00025: val_acc did not improve from 0.94909
# Epoch 26/100
# Learning rate:  0.001
#  - 119s - loss: 0.0830 - acc: 0.9957 - val_loss: 0.3838 - val_acc: 0.9341
#
# Epoch 00026: val_acc did not improve from 0.94909
# Epoch 27/100
# Learning rate:  0.001
#  - 119s - loss: 0.0796 - acc: 0.9951 - val_loss: 0.3065 - val_acc: 0.9494
#
# Epoch 00027: val_acc improved from 0.94909 to 0.94941, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.027.hg
# Epoch 28/100
# Learning rate:  0.001
#  - 119s - loss: 0.0778 - acc: 0.9949 - val_loss: 0.4235 - val_acc: 0.9227
#
# Epoch 00028: val_acc did not improve from 0.94941
# Epoch 29/100
# Learning rate:  0.001
#  - 119s - loss: 0.0753 - acc: 0.9952 - val_loss: 0.3427 - val_acc: 0.9393
#
# Epoch 00029: val_acc did not improve from 0.94941
# Epoch 30/100
# Learning rate:  0.001
#  - 119s - loss: 0.0729 - acc: 0.9953 - val_loss: 0.3715 - val_acc: 0.9308
#
# Epoch 00030: val_acc did not improve from 0.94941
# Epoch 31/100
# Learning rate:  0.001
#  - 120s - loss: 0.0663 - acc: 0.9964 - val_loss: 0.3664 - val_acc: 0.9371
#
# Epoch 00031: val_acc did not improve from 0.94941
# Epoch 32/100
# Learning rate:  0.001
#  - 120s - loss: 0.0673 - acc: 0.9958 - val_loss: 0.3126 - val_acc: 0.9480
#
# Epoch 00032: val_acc did not improve from 0.94941
# Epoch 33/100
# Learning rate:  0.001
#  - 119s - loss: 0.0636 - acc: 0.9958 - val_loss: 0.3432 - val_acc: 0.9418
#
# Epoch 00033: val_acc did not improve from 0.94941
# Epoch 34/100
# Learning rate:  0.001
#  - 119s - loss: 0.0633 - acc: 0.9960 - val_loss: 0.2654 - val_acc: 0.9557
#
# Epoch 00034: val_acc improved from 0.94941 to 0.95570, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.034.hg
# Epoch 35/100
# Learning rate:  0.001
#  - 119s - loss: 0.0576 - acc: 0.9967 - val_loss: 0.7357 - val_acc: 0.8868
#
# Epoch 00035: val_acc did not improve from 0.95570
# Epoch 36/100
# Learning rate:  0.001
#  - 119s - loss: 0.0591 - acc: 0.9959 - val_loss: 0.4647 - val_acc: 0.9213
#
# Epoch 00036: val_acc did not improve from 0.95570
# Epoch 37/100
# Learning rate:  0.001
#  - 119s - loss: 0.0566 - acc: 0.9965 - val_loss: 0.3160 - val_acc: 0.9475
#
# Epoch 00037: val_acc did not improve from 0.95570
# Epoch 38/100
# Learning rate:  0.001
#  - 119s - loss: 0.0530 - acc: 0.9969 - val_loss: 0.3989 - val_acc: 0.9345
#
# Epoch 00038: val_acc did not improve from 0.95570
# Epoch 39/100
# Learning rate:  0.001
#  - 119s - loss: 0.0552 - acc: 0.9963 - val_loss: 0.3759 - val_acc: 0.9335
#
# Epoch 00039: val_acc did not improve from 0.95570
# Epoch 40/100
# Learning rate:  0.001
#  - 119s - loss: 0.0502 - acc: 0.9972 - val_loss: 0.7345 - val_acc: 0.8857
#
# Epoch 00040: val_acc did not improve from 0.95570
# Epoch 41/100
# Learning rate:  0.001
#  - 119s - loss: 0.0537 - acc: 0.9959 - val_loss: 0.5650 - val_acc: 0.9096
#
# Epoch 00041: val_acc did not improve from 0.95570
# Epoch 42/100
# Learning rate:  0.001
#  - 119s - loss: 0.0488 - acc: 0.9971 - val_loss: 0.4297 - val_acc: 0.9316
#
# Epoch 00042: val_acc did not improve from 0.95570
# Epoch 43/100
# Learning rate:  0.001
#  - 119s - loss: 0.0451 - acc: 0.9977 - val_loss: 0.3695 - val_acc: 0.9432
#
# Epoch 00043: val_acc did not improve from 0.95570
# Epoch 44/100
# Learning rate:  0.001
#  - 119s - loss: 0.0465 - acc: 0.9970 - val_loss: 0.5593 - val_acc: 0.9030
#
# Epoch 00044: val_acc did not improve from 0.95570
# Epoch 45/100
# Learning rate:  0.001
#  - 119s - loss: 0.0488 - acc: 0.9967 - val_loss: 0.3127 - val_acc: 0.9477
#
# Epoch 00045: val_acc did not improve from 0.95570
# Epoch 46/100
# Learning rate:  0.001
#  - 119s - loss: 0.0427 - acc: 0.9974 - val_loss: 0.3373 - val_acc: 0.9422
#
# Epoch 00046: val_acc did not improve from 0.95570
# Epoch 47/100
# Learning rate:  0.001
#  - 119s - loss: 0.0443 - acc: 0.9970 - val_loss: 0.3587 - val_acc: 0.9431
#
# Epoch 00047: val_acc did not improve from 0.95570
# Epoch 48/100
# Learning rate:  0.001
#  - 119s - loss: 0.0432 - acc: 0.9972 - val_loss: 0.3746 - val_acc: 0.9382
#
# Epoch 00048: val_acc did not improve from 0.95570
# Epoch 49/100
# Learning rate:  0.001
#  - 119s - loss: 0.0417 - acc: 0.9976 - val_loss: 0.3899 - val_acc: 0.9353
#
# Epoch 00049: val_acc did not improve from 0.95570
# Epoch 50/100
# Learning rate:  0.001
#  - 119s - loss: 0.0390 - acc: 0.9976 - val_loss: 0.4432 - val_acc: 0.9228
#
# Epoch 00050: val_acc did not improve from 0.95570
# Epoch 51/100
# Learning rate:  0.001
#  - 119s - loss: 0.0406 - acc: 0.9975 - val_loss: 0.6964 - val_acc: 0.8877
#
# Epoch 00051: val_acc did not improve from 0.95570
# Epoch 52/100
# Learning rate:  0.001
#  - 119s - loss: 0.0405 - acc: 0.9972 - val_loss: 0.4888 - val_acc: 0.9247
#
# Epoch 00052: val_acc did not improve from 0.95570
# Epoch 53/100
# Learning rate:  0.001
#  - 119s - loss: 0.0355 - acc: 0.9983 - val_loss: 0.4225 - val_acc: 0.9341
#
# Epoch 00053: val_acc did not improve from 0.95570
# Epoch 54/100
# Learning rate:  0.001
#  - 119s - loss: 0.0395 - acc: 0.9971 - val_loss: 1.5187 - val_acc: 0.7909
#
# Epoch 00054: val_acc did not improve from 0.95570
# Epoch 55/100
# Learning rate:  0.001
#  - 119s - loss: 0.0343 - acc: 0.9982 - val_loss: 0.4867 - val_acc: 0.9258
#
# Epoch 00055: val_acc did not improve from 0.95570
# Epoch 56/100
# Learning rate:  0.001
#  - 119s - loss: 0.0398 - acc: 0.9969 - val_loss: 0.3184 - val_acc: 0.9496
#
# Epoch 00056: val_acc did not improve from 0.95570
# Epoch 57/100
# Learning rate:  0.001
#  - 119s - loss: 0.0334 - acc: 0.9984 - val_loss: 0.3472 - val_acc: 0.9445
#
# Epoch 00057: val_acc did not improve from 0.95570
# Epoch 58/100
# Learning rate:  0.001
#  - 119s - loss: 0.0343 - acc: 0.9977 - val_loss: 0.4486 - val_acc: 0.9276
#
# Epoch 00058: val_acc did not improve from 0.95570
# Epoch 59/100
# Learning rate:  0.001
#  - 119s - loss: 0.0360 - acc: 0.9973 - val_loss: 2.0996 - val_acc: 0.7392
#
# Epoch 00059: val_acc did not improve from 0.95570
# Epoch 60/100
# Learning rate:  0.001
#  - 119s - loss: 0.0344 - acc: 0.9978 - val_loss: 0.4005 - val_acc: 0.9375
#
# Epoch 00060: val_acc did not improve from 0.95570
# Epoch 61/100
# Learning rate:  0.001
#  - 119s - loss: 0.0353 - acc: 0.9977 - val_loss: 0.3506 - val_acc: 0.9433
#
# Epoch 00061: val_acc did not improve from 0.95570
# Epoch 62/100
# Learning rate:  0.001
#  - 119s - loss: 0.0304 - acc: 0.9986 - val_loss: 1.7107 - val_acc: 0.7782
#
# Epoch 00062: val_acc did not improve from 0.95570
# Epoch 63/100
# Learning rate:  0.001
#  - 120s - loss: 0.0320 - acc: 0.9980 - val_loss: 0.4279 - val_acc: 0.9288
#
# Epoch 00063: val_acc did not improve from 0.95570
# Epoch 64/100
# Learning rate:  0.001
#  - 119s - loss: 0.0334 - acc: 0.9976 - val_loss: 0.7823 - val_acc: 0.8884
#
# Epoch 00064: val_acc did not improve from 0.95570
# Epoch 65/100
# Learning rate:  0.001
#  - 119s - loss: 0.0323 - acc: 0.9981 - val_loss: 0.8081 - val_acc: 0.8770
#
# Epoch 00065: val_acc did not improve from 0.95570
# Epoch 66/100
# Learning rate:  0.001
#  - 119s - loss: 0.0293 - acc: 0.9985 - val_loss: 0.3722 - val_acc: 0.9433
#
# Epoch 00066: val_acc did not improve from 0.95570
# Epoch 67/100
# Learning rate:  0.001
#  - 119s - loss: 0.0317 - acc: 0.9977 - val_loss: 2.0104 - val_acc: 0.7772
#
# Epoch 00067: val_acc did not improve from 0.95570
# Epoch 68/100
# Learning rate:  0.001
#  - 119s - loss: 0.0279 - acc: 0.9987 - val_loss: 0.5414 - val_acc: 0.9151
#
# Epoch 00068: val_acc did not improve from 0.95570
# Epoch 69/100
# Learning rate:  0.001
#  - 119s - loss: 0.0328 - acc: 0.9975 - val_loss: 0.4235 - val_acc: 0.9351
#
# Epoch 00069: val_acc did not improve from 0.95570
# Epoch 70/100
# Learning rate:  0.001
#  - 118s - loss: 0.0304 - acc: 0.9980 - val_loss: 0.4188 - val_acc: 0.9327
#
# Epoch 00070: val_acc did not improve from 0.95570
# Epoch 71/100
# Learning rate:  0.001
#  - 119s - loss: 0.0298 - acc: 0.9980 - val_loss: 0.7212 - val_acc: 0.8892
#
# Epoch 00071: val_acc did not improve from 0.95570
# Epoch 72/100
# Learning rate:  0.001
#  - 118s - loss: 0.0281 - acc: 0.9984 - val_loss: 0.3967 - val_acc: 0.9398
#
# Epoch 00072: val_acc did not improve from 0.95570
# Epoch 73/100
# Learning rate:  0.001
#  - 118s - loss: 0.0256 - acc: 0.9988 - val_loss: 0.3573 - val_acc: 0.9458
#
# Epoch 00073: val_acc did not improve from 0.95570
# Epoch 74/100
# Learning rate:  0.001
#  - 118s - loss: 0.0270 - acc: 0.9981 - val_loss: 0.8131 - val_acc: 0.8798
#
# Epoch 00074: val_acc did not improve from 0.95570
# Epoch 75/100
# Learning rate:  0.001
#  - 118s - loss: 0.0313 - acc: 0.9975 - val_loss: 0.8994 - val_acc: 0.8759
#
# Epoch 00075: val_acc did not improve from 0.95570
# Epoch 76/100
# Learning rate:  0.001
#  - 118s - loss: 0.0265 - acc: 0.9987 - val_loss: 1.0635 - val_acc: 0.8531
#
# Epoch 00076: val_acc did not improve from 0.95570
# Epoch 77/100
# Learning rate:  0.001
#  - 119s - loss: 0.0275 - acc: 0.9982 - val_loss: 0.4443 - val_acc: 0.9294
#
# Epoch 00077: val_acc did not improve from 0.95570
# Epoch 78/100
# Learning rate:  0.001
#  - 119s - loss: 0.0262 - acc: 0.9986 - val_loss: 1.7264 - val_acc: 0.7718
#
# Epoch 00078: val_acc did not improve from 0.95570
# Epoch 79/100
# Learning rate:  0.001
#  - 119s - loss: 0.0274 - acc: 0.9981 - val_loss: 1.3153 - val_acc: 0.8335
#
# Epoch 00079: val_acc did not improve from 0.95570
# Epoch 80/100
# Learning rate:  0.001
#  - 118s - loss: 0.0262 - acc: 0.9987 - val_loss: 0.4370 - val_acc: 0.9315
#
# Epoch 00080: val_acc did not improve from 0.95570
# Epoch 81/100
# Learning rate:  0.001
#  - 119s - loss: 0.0256 - acc: 0.9984 - val_loss: 2.1927 - val_acc: 0.7377
#
# Epoch 00081: val_acc did not improve from 0.95570
# Epoch 82/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0222 - acc: 0.9995 - val_loss: 0.3186 - val_acc: 0.9496
#
# Epoch 00082: val_acc did not improve from 0.95570
# Epoch 83/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0201 - acc: 0.9999 - val_loss: 0.3113 - val_acc: 0.9508
#
# Epoch 00083: val_acc did not improve from 0.95570
# Epoch 84/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0192 - acc: 0.9999 - val_loss: 0.3061 - val_acc: 0.9519
#
# Epoch 00084: val_acc did not improve from 0.95570
# Epoch 85/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0184 - acc: 0.9999 - val_loss: 0.3026 - val_acc: 0.9528
#
# Epoch 00085: val_acc did not improve from 0.95570
# Epoch 86/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0173 - acc: 0.9999 - val_loss: 0.2977 - val_acc: 0.9543
#
# Epoch 00086: val_acc did not improve from 0.95570
# Epoch 87/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0161 - acc: 0.9999 - val_loss: 0.2926 - val_acc: 0.9554
#
# Epoch 00087: val_acc did not improve from 0.95570
# Epoch 88/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0147 - acc: 0.9999 - val_loss: 0.2877 - val_acc: 0.9568
#
# Epoch 00088: val_acc improved from 0.95570 to 0.95682, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.088.hg
# Epoch 89/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0132 - acc: 0.9999 - val_loss: 0.2873 - val_acc: 0.9562
#
# Epoch 00089: val_acc did not improve from 0.95682
# Epoch 90/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0116 - acc: 0.9999 - val_loss: 0.2842 - val_acc: 0.9569
#
# Epoch 00090: val_acc improved from 0.95682 to 0.95691, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.090.hg
# Epoch 91/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0103 - acc: 0.9999 - val_loss: 0.2865 - val_acc: 0.9562
#
# Epoch 00091: val_acc did not improve from 0.95691
# Epoch 92/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0093 - acc: 0.9998 - val_loss: 0.2865 - val_acc: 0.9559
#
# Epoch 00092: val_acc did not improve from 0.95691
# Epoch 93/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0084 - acc: 0.9999 - val_loss: 0.2832 - val_acc: 0.9567
#
# Epoch 00093: val_acc did not improve from 0.95691
# Epoch 94/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0079 - acc: 0.9999 - val_loss: 0.2782 - val_acc: 0.9577
#
# Epoch 00094: val_acc improved from 0.95691 to 0.95768, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.094.hg
# Epoch 95/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0075 - acc: 0.9999 - val_loss: 0.2990 - val_acc: 0.9541
#
# Epoch 00095: val_acc did not improve from 0.95768
# Epoch 96/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0070 - acc: 1.0000 - val_loss: 0.2714 - val_acc: 0.9594
#
# Epoch 00096: val_acc improved from 0.95768 to 0.95938, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_32/checkpoint.096.hg
# Epoch 97/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0066 - acc: 0.9999 - val_loss: 0.2723 - val_acc: 0.9589
#
# Epoch 00097: val_acc did not improve from 0.95938
# Epoch 98/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0062 - acc: 0.9999 - val_loss: 0.2873 - val_acc: 0.9579
#
# Epoch 00098: val_acc did not improve from 0.95938
# Epoch 99/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0059 - acc: 0.9999 - val_loss: 0.2696 - val_acc: 0.9588
#
# Epoch 00099: val_acc did not improve from 0.95938
# Epoch 100/100
# Learning rate:  0.0001
#  - 119s - loss: 0.0060 - acc: 0.9999 - val_loss: 0.3545 - val_acc: 0.9470
#
# Epoch 00100: val_acc did not improve from 0.95938
# Model:  resnet56v2_1_100_32 , Loss:  0.3731551211440997 , Accuracy:  0.9445023543387946
# Done!

# %%
print('=====output=====')
# !ls '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_2/resnet56v2'
# Out:
# =====output=====
# accuracy.png	   checkpoint.002.hg  csv_eva.csv  loss.png  weights.h5
# checkpoint.001.hg  checkpoint.006.hg  csv_fit.csv  model.h5
