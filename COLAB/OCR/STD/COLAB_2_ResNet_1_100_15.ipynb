# %%
# -*- coding: utf-8 -*-
# Author: Inyong Hwang (lkan6004@gmail.com)
# Date: 2019-06-16-Sun
# Korean Character STR 15*15 by ResNet epoch=1~100 

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
print('=====Google Drive=====')
# !ls '/content/drive/My Drive/'
print('=====input=====')
# !ls '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/PKL_15v4/'
# Out:
# =====Google Drive=====
#  논문			      'Colab Notebooks'   Lab-Desktop   PUBLIC
# 'AI 사물인식 해커톤 (2).zip'   Dataset		  Program       USB
# =====input=====
# images.pkl  labels.pkl

# %%
# read directory
import sys
import os
import pickle
import numpy as np
from keras.utils import to_categorical
from collections import Counter
from sklearn.model_selection import train_test_split
from keras import layers
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2
from keras.models import Model
from keras import backend as k
import matplotlib.pyplot as plt
import pandas as pd

model_name = 'resnet56v2_1_100_15'
input_dir = '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/PKL_15v4/'
output_dir = '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/'

if os.path.isdir(output_dir):
    pass
else:
    os.mkdir(output_dir)

if os.path.isdir(output_dir + str(model_name)):
    pass
else:
    os.mkdir(output_dir + str(model_name))
   
filenames = os.listdir(input_dir)
for filename in filenames:
    if 'image' in filename:
        print('loading %s' % filename)
        with open(input_dir + filename, 'rb') as f:
            X = pickle.load(f)
        print('loaded!')
    else:
        print('loading %s' % filename)
        with open(input_dir + filename, 'rb') as f:
            Y = pickle.load(f)
        print('loaded!')

X = np.array(X)
X = X[:, :, :, np.newaxis]
input_shape = X.shape[1:]
Y = np.array(Y)
num_classes = len(Counter(Y))
Y = to_categorical(Y, num_classes)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=37, shuffle=True)
print('# of images: %d' % len(X))
print('Shape of images:', X.shape[1:])
print('# of train set: %d' % len(X_train), '# of test set: %d' % len(X_test))
del X, Y

# Define Model
version = 2
n = 6
depth = n * 9 + 2
batch_size = 128
epochs = 100 # 200
model_type = 'ResNet%dv%d' % (depth, version)


def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(filters=filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v2(input_shape=input_shape, depth=depth, classes=num_classes):
    filters_in = 16
    resnet_blocks = int((depth - 2) / 9)

    i = Input(shape=input_shape, name='Input_Image')
    x = resnet_layer(inputs=i, filters=filters_in, conv_first=True)
    for stage in range(3):
        for resnet_block in range(resnet_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                filters_out = filters_in * 4
                if resnet_block == 0:
                    activation = None
                    batch_normalization = False
            else:
                filters_out = filters_in * 2
                if resnet_block == 0:
                    strides = 2
            y = resnet_layer(inputs=x, filters=filters_in, kernel_size=1, strides=strides, activation=activation, batch_normalization=batch_normalization, conv_first=False)
            y = resnet_layer(inputs=y, filters=filters_in, conv_first=False)
            y = resnet_layer(inputs=y, filters=filters_out, kernel_size=1, conv_first=False)
            if resnet_block == 0:
                x = resnet_layer(inputs=x, filters=filters_out, kernel_size=1, strides=strides, activation=None, batch_normalization=False)
            x = layers.add([x, y])
        filters_in = filters_out

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # x = AveragePooling2D(pool_size=8)(x)
    x = Flatten()(x)
    y = Dense(classes, activation='softmax', kernel_initializer='he_normal')(x)
    model = Model(inputs=i, outputs=y)
    return model


model = resnet_v2(input_shape=input_shape, depth=depth)
model.summary()
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=lr_schedule(0)), metrics=['accuracy'])
print(model_type)
checkpoint = ModelCheckpoint(filepath=output_dir + str(model_name) + '/checkpoint.{epoch:03d}.hg',
                             monitor='val_acc',
                             verbose=2,
                             save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]
fit = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=2, callbacks=callbacks, validation_split=0.2, initial_epoch=0)
eva = model.evaluate(X_test, Y_test, verbose=2)


def plot_loss(history, output_dir, model_name):
    plt.clf()
    plt_loss = plt
    plt_loss.plot(history.history['loss'])
    plt_loss.plot(history.history['val_loss'])
    plt_loss.title('Model Loss')
    plt_loss.xlabel('Epoch')
    plt_loss.ylabel('Loss')
    plt_loss.legend(['Train', 'Test'], loc=0)
    figure = output_dir + str(model_name) + '/loss.png'
    plt_loss.savefig(figure, dpi=1080)


def plot_acc(history, output_dir, model_name):
    plt.clf()
    plt_acc = plt
    plt_acc.plot(history.history['acc'])
    plt_acc.plot(history.history['val_acc'])
    plt_acc.title('Model Accuracy')
    plt_acc.xlabel('Epoch')
    plt_acc.ylabel('Accuracy')
    plt_acc.legend(['Train', 'Test'], loc=0)
    figure = output_dir + str(model_name) + '/accuracy.png'
    plt_acc.savefig(figure, dpi=1080)


def csv_fit(history, output_dir, model_name):
    train_data = pd.DataFrame(history.history)
    train_data.to_csv(output_dir + str(model_name) + '/csv_fit.csv')
    return None


def csv_eva(history, output_dir, model_name):
    test_data = pd.DataFrame(history)
    test_data = test_data.T
    if len(history) == 5:
        test_data_header = ['test_loss', 'test_acc', 'precision', 'recall', 'f1score']
    else:
        test_data_header = ['test_loss', 'test_acc']
    test_data.to_csv(output_dir + str(model_name) + '/csv_eva.csv', header=test_data_header)
    return None


print('Model: ', model_name, ', Loss: ', eva[0], ', Accuracy: ', eva[1])
plot_loss(history=fit, output_dir=output_dir, model_name=model_name)
plot_acc(history=fit, output_dir=output_dir, model_name=model_name)
csv_fit(history=fit, output_dir=output_dir, model_name=model_name)
csv_eva(history=eva, output_dir=output_dir, model_name=model_name)
model.save(output_dir + str(model_name) + '/model.h5')
model_json = model.to_json()
with open(output_dir + str(model_name) + '/model.json', 'w') as json_file:
    json_file.write(model_json)
    json_file.close()
model_yaml = model.to_yaml()
with open(output_dir + str(model_name) + '/model.yaml', 'w') as yaml_file:
    yaml_file.write(model_yaml)
    yaml_file.close()
model.save_weights(output_dir + str(model_name) + '/weights.h5')
print('Done!')
# Out:
# Using TensorFlow backend.
# loading labels.pkl
# loaded!
# loading images.pkl
# loaded!
# WARNING: Logging before flag parsing goes to stderr.
# W0616 14:16:13.190138 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0616 14:16:13.220770 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0616 14:16:13.222336 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0616 14:16:13.267628 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0616 14:16:13.268482 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# # of images: 139104
# Shape of images: (15, 15, 1)
# # of train set: 111283 # of test set: 27821
# W0616 14:16:16.756546 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0616 14:16:21.931150 139682925594496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input_Image (InputLayer)        (None, 15, 15, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 15, 15, 16)   160         Input_Image[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 15, 15, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 15, 15, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 15, 15, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 15, 15, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 15, 15, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 15, 15, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 15, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 15, 15, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 15, 15, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 15, 15, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 15, 15, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 15, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 15, 15, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15, 15, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 15, 15, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 15, 15, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 15, 15, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 15, 15, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 15, 15, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 15, 15, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 15, 15, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 15, 15, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 15, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 15, 15, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 15, 15, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 15, 15, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 15, 15, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 15, 15, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 15, 15, 64)   1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 15, 15, 64)   0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 15, 15, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 15, 15, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 15, 15, 16)   1040        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 15, 15, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 15, 15, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 15, 15, 16)   2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 15, 15, 16)   64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 15, 15, 16)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 15, 15, 64)   1088        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 15, 15, 64)   0           add_3[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 15, 15, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 15, 15, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 15, 15, 16)   1040        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 15, 15, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 15, 15, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 15, 15, 16)   2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 15, 15, 16)   64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 15, 15, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 15, 15, 64)   1088        activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 15, 15, 64)   0           add_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 15, 15, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 15, 15, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 15, 15, 16)   1040        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 15, 15, 16)   64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 15, 15, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 15, 15, 16)   2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 15, 15, 16)   64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 15, 15, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 15, 15, 64)   1088        activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 15, 15, 64)   0           add_5[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 15, 15, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 15, 15, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     4160        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 64)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 64)     36928       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 64)     256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 64)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 128)    8320        add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    8320        activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 128)    0           conv2d_24[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 128)    512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 128)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     8256        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 64)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 64)     36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 64)     256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 64)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    8320        activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 128)    0           add_7[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 128)    512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 128)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 64)     8256        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 64)     256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 64)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 64)     36928       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 64)     256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 64)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 128)    8320        activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 128)    0           add_8[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 128)    512         add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 128)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     8256        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     36928       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 64)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 128)    8320        activation_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 128)    0           add_9[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 128)    512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 128)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 64)     8256        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 64)     256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 64)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 64)     36928       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 64)     256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 64)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 128)    8320        activation_33[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 128)    0           add_10[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 128)    512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 128)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     8256        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 64)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     36928       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 64)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 128)    8320        activation_36[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 128)    0           add_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 128)    512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 128)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    16512       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 4, 4, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 4, 4, 128)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 128)    147584      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 128)    512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 4, 4, 128)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 256)    33024       add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 256)    33024       activation_39[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 256)    0           conv2d_43[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 256)    1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 4, 4, 256)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 128)    32896       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 128)    512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 4, 128)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 128)    147584      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 128)    512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 4, 128)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 256)    33024       activation_42[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 256)    0           add_13[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 4, 256)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 128)    32896       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 128)    147584      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 128)    512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 4, 128)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 256)    33024       activation_45[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 256)    0           add_14[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 4, 256)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 128)    32896       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 128)    512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 128)    147584      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 128)    512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 256)    33024       activation_48[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 4, 256)    0           add_15[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 4, 4, 256)    1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 256)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 128)    32896       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 4, 4, 128)    512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 4, 4, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 128)    147584      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 4, 4, 128)    512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 4, 4, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 256)    33024       activation_51[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 4, 4, 256)    0           add_16[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 4, 4, 256)    1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 4, 4, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 128)    32896       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 4, 4, 128)    512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 4, 4, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 128)    147584      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 4, 4, 128)    512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 4, 4, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 256)    33024       activation_54[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 4, 4, 256)    0           add_17[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 4, 4, 256)    1024        add_18[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 4, 4, 256)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           activation_55[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1008)         4129776     flatten_1[0][0]
# ==================================================================================================
# Total params: 5,800,656
# Trainable params: 5,790,256
# Non-trainable params: 10,400
# __________________________________________________________________________________________________
# Learning rate:  0.001
# ResNet56v2
# W0616 14:16:22.943289 139682925594496 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 89026 samples, validate on 22257 samples
# Epoch 1/100
# Learning rate:  0.001
#  - 66s - loss: 4.5160 - acc: 0.3186 - val_loss: 2.9694 - val_acc: 0.5035
#
# Epoch 00001: val_acc improved from -inf to 0.50353, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.001.hg
# Epoch 2/100
# Learning rate:  0.001
#  - 49s - loss: 2.0642 - acc: 0.6694 - val_loss: 2.2215 - val_acc: 0.6267
#
# Epoch 00002: val_acc improved from 0.50353 to 0.62672, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.002.hg
# Epoch 3/100
# Learning rate:  0.001
#  - 49s - loss: 1.4893 - acc: 0.7773 - val_loss: 2.1836 - val_acc: 0.6180
#
# Epoch 00003: val_acc did not improve from 0.62672
# Epoch 4/100
# Learning rate:  0.001
#  - 48s - loss: 1.1798 - acc: 0.8357 - val_loss: 1.8401 - val_acc: 0.6823
#
# Epoch 00004: val_acc improved from 0.62672 to 0.68230, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.004.hg
# Epoch 5/100
# Learning rate:  0.001
#  - 49s - loss: 0.9981 - acc: 0.8691 - val_loss: 1.9217 - val_acc: 0.6697
#
# Epoch 00005: val_acc did not improve from 0.68230
# Epoch 6/100
# Learning rate:  0.001
#  - 49s - loss: 0.8724 - acc: 0.8940 - val_loss: 2.0002 - val_acc: 0.6654
#
# Epoch 00006: val_acc did not improve from 0.68230
# Epoch 7/100
# Learning rate:  0.001
#  - 49s - loss: 0.7796 - acc: 0.9118 - val_loss: 1.8672 - val_acc: 0.6814
#
# Epoch 00007: val_acc did not improve from 0.68230
# Epoch 8/100
# Learning rate:  0.001
#  - 48s - loss: 0.7106 - acc: 0.9229 - val_loss: 1.8037 - val_acc: 0.6890
#
# Epoch 00008: val_acc improved from 0.68230 to 0.68904, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.008.hg
# Epoch 9/100
# Learning rate:  0.001
#  - 49s - loss: 0.6692 - acc: 0.9275 - val_loss: 2.1379 - val_acc: 0.6473
#
# Epoch 00009: val_acc did not improve from 0.68904
# Epoch 10/100
# Learning rate:  0.001
#  - 48s - loss: 0.6295 - acc: 0.9333 - val_loss: 1.7914 - val_acc: 0.7068
#
# Epoch 00010: val_acc improved from 0.68904 to 0.70683, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.010.hg
# Epoch 11/100
# Learning rate:  0.001
#  - 49s - loss: 0.5918 - acc: 0.9395 - val_loss: 2.2912 - val_acc: 0.6357
#
# Epoch 00011: val_acc did not improve from 0.70683
# Epoch 12/100
# Learning rate:  0.001
#  - 49s - loss: 0.5611 - acc: 0.9427 - val_loss: 1.9643 - val_acc: 0.6835
#
# Epoch 00012: val_acc did not improve from 0.70683
# Epoch 13/100
# Learning rate:  0.001
#  - 48s - loss: 0.5386 - acc: 0.9456 - val_loss: 1.9882 - val_acc: 0.6791
#
# Epoch 00013: val_acc did not improve from 0.70683
# Epoch 14/100
# Learning rate:  0.001
#  - 48s - loss: 0.5132 - acc: 0.9487 - val_loss: 2.0709 - val_acc: 0.6735
#
# Epoch 00014: val_acc did not improve from 0.70683
# Epoch 15/100
# Learning rate:  0.001
#  - 48s - loss: 0.4924 - acc: 0.9506 - val_loss: 1.9322 - val_acc: 0.7027
#
# Epoch 00015: val_acc did not improve from 0.70683
# Epoch 16/100
# Learning rate:  0.001
#  - 48s - loss: 0.4683 - acc: 0.9541 - val_loss: 2.0608 - val_acc: 0.6720
#
# Epoch 00016: val_acc did not improve from 0.70683
# Epoch 17/100
# Learning rate:  0.001
#  - 48s - loss: 0.4528 - acc: 0.9550 - val_loss: 2.0917 - val_acc: 0.6509
#
# Epoch 00017: val_acc did not improve from 0.70683
# Epoch 18/100
# Learning rate:  0.001
#  - 48s - loss: 0.4354 - acc: 0.9578 - val_loss: 1.7139 - val_acc: 0.6965
#
# Epoch 00018: val_acc did not improve from 0.70683
# Epoch 19/100
# Learning rate:  0.001
#  - 48s - loss: 0.4257 - acc: 0.9580 - val_loss: 2.9987 - val_acc: 0.5774
#
# Epoch 00019: val_acc did not improve from 0.70683
# Epoch 20/100
# Learning rate:  0.001
#  - 48s - loss: 0.4117 - acc: 0.9588 - val_loss: 2.0448 - val_acc: 0.6784
#
# Epoch 00020: val_acc did not improve from 0.70683
# Epoch 21/100
# Learning rate:  0.001
#  - 48s - loss: 0.4063 - acc: 0.9588 - val_loss: 1.8545 - val_acc: 0.6989
#
# Epoch 00021: val_acc did not improve from 0.70683
# Epoch 22/100
# Learning rate:  0.001
#  - 48s - loss: 0.3849 - acc: 0.9635 - val_loss: 3.1193 - val_acc: 0.5595
#
# Epoch 00022: val_acc did not improve from 0.70683
# Epoch 23/100
# Learning rate:  0.001
#  - 48s - loss: 0.3781 - acc: 0.9623 - val_loss: 2.2698 - val_acc: 0.6558
#
# Epoch 00023: val_acc did not improve from 0.70683
# Epoch 24/100
# Learning rate:  0.001
#  - 48s - loss: 0.3716 - acc: 0.9627 - val_loss: 1.9631 - val_acc: 0.6836
#
# Epoch 00024: val_acc did not improve from 0.70683
# Epoch 25/100
# Learning rate:  0.001
#  - 48s - loss: 0.3566 - acc: 0.9658 - val_loss: 2.0929 - val_acc: 0.6811
#
# Epoch 00025: val_acc did not improve from 0.70683
# Epoch 26/100
# Learning rate:  0.001
#  - 48s - loss: 0.3503 - acc: 0.9651 - val_loss: 1.8726 - val_acc: 0.6913
#
# Epoch 00026: val_acc did not improve from 0.70683
# Epoch 27/100
# Learning rate:  0.001
#  - 48s - loss: 0.3483 - acc: 0.9651 - val_loss: 1.8367 - val_acc: 0.7038
#
# Epoch 00027: val_acc did not improve from 0.70683
# Epoch 28/100
# Learning rate:  0.001
#  - 48s - loss: 0.3331 - acc: 0.9683 - val_loss: 2.9464 - val_acc: 0.5906
#
# Epoch 00028: val_acc did not improve from 0.70683
# Epoch 29/100
# Learning rate:  0.001
#  - 48s - loss: 0.3309 - acc: 0.9674 - val_loss: 1.9374 - val_acc: 0.6888
#
# Epoch 00029: val_acc did not improve from 0.70683
# Epoch 30/100
# Learning rate:  0.001
#  - 48s - loss: 0.3194 - acc: 0.9695 - val_loss: 3.4978 - val_acc: 0.5503
#
# Epoch 00030: val_acc did not improve from 0.70683
# Epoch 31/100
# Learning rate:  0.001
#  - 48s - loss: 0.3226 - acc: 0.9664 - val_loss: 2.5111 - val_acc: 0.6368
#
# Epoch 00031: val_acc did not improve from 0.70683
# Epoch 32/100
# Learning rate:  0.001
#  - 47s - loss: 0.3106 - acc: 0.9704 - val_loss: 3.4289 - val_acc: 0.5780
#
# Epoch 00032: val_acc did not improve from 0.70683
# Epoch 33/100
# Learning rate:  0.001
#  - 47s - loss: 0.3058 - acc: 0.9705 - val_loss: 2.1878 - val_acc: 0.6431
#
# Epoch 00033: val_acc did not improve from 0.70683
# Epoch 34/100
# Learning rate:  0.001
#  - 48s - loss: 0.3010 - acc: 0.9710 - val_loss: 2.7932 - val_acc: 0.6070
#
# Epoch 00034: val_acc did not improve from 0.70683
# Epoch 35/100
# Learning rate:  0.001
#  - 48s - loss: 0.2944 - acc: 0.9709 - val_loss: 2.1910 - val_acc: 0.6700
#
# Epoch 00035: val_acc did not improve from 0.70683
# Epoch 36/100
# Learning rate:  0.001
#  - 47s - loss: 0.2894 - acc: 0.9717 - val_loss: 2.1042 - val_acc: 0.6815
#
# Epoch 00036: val_acc did not improve from 0.70683
# Epoch 37/100
# Learning rate:  0.001
#  - 47s - loss: 0.2918 - acc: 0.9702 - val_loss: 2.2628 - val_acc: 0.6679
#
# Epoch 00037: val_acc did not improve from 0.70683
# Epoch 38/100
# Learning rate:  0.001
#  - 47s - loss: 0.2786 - acc: 0.9731 - val_loss: 2.1370 - val_acc: 0.6683
#
# Epoch 00038: val_acc did not improve from 0.70683
# Epoch 39/100
# Learning rate:  0.001
#  - 48s - loss: 0.2766 - acc: 0.9725 - val_loss: 2.1297 - val_acc: 0.6854
#
# Epoch 00039: val_acc did not improve from 0.70683
# Epoch 40/100
# Learning rate:  0.001
#  - 48s - loss: 0.2734 - acc: 0.9736 - val_loss: 2.2267 - val_acc: 0.6612
#
# Epoch 00040: val_acc did not improve from 0.70683
# Epoch 41/100
# Learning rate:  0.001
#  - 48s - loss: 0.2659 - acc: 0.9739 - val_loss: 2.1868 - val_acc: 0.6738
#
# Epoch 00041: val_acc did not improve from 0.70683
# Epoch 42/100
# Learning rate:  0.001
#  - 48s - loss: 0.2621 - acc: 0.9746 - val_loss: 2.3298 - val_acc: 0.6645
#
# Epoch 00042: val_acc did not improve from 0.70683
# Epoch 43/100
# Learning rate:  0.001
#  - 47s - loss: 0.2639 - acc: 0.9732 - val_loss: 2.0282 - val_acc: 0.6809
#
# Epoch 00043: val_acc did not improve from 0.70683
# Epoch 44/100
# Learning rate:  0.001
#  - 48s - loss: 0.2523 - acc: 0.9755 - val_loss: 2.1030 - val_acc: 0.6887
#
# Epoch 00044: val_acc did not improve from 0.70683
# Epoch 45/100
# Learning rate:  0.001
#  - 47s - loss: 0.2531 - acc: 0.9748 - val_loss: 3.4404 - val_acc: 0.5765
#
# Epoch 00045: val_acc did not improve from 0.70683
# Epoch 46/100
# Learning rate:  0.001
#  - 47s - loss: 0.2489 - acc: 0.9756 - val_loss: 2.2168 - val_acc: 0.6848
#
# Epoch 00046: val_acc did not improve from 0.70683
# Epoch 47/100
# Learning rate:  0.001
#  - 47s - loss: 0.2462 - acc: 0.9755 - val_loss: 2.1292 - val_acc: 0.6941
#
# Epoch 00047: val_acc did not improve from 0.70683
# Epoch 48/100
# Learning rate:  0.001
#  - 48s - loss: 0.2407 - acc: 0.9764 - val_loss: 2.1140 - val_acc: 0.6792
#
# Epoch 00048: val_acc did not improve from 0.70683
# Epoch 49/100
# Learning rate:  0.001
#  - 47s - loss: 0.2395 - acc: 0.9754 - val_loss: 2.1669 - val_acc: 0.6691
#
# Epoch 00049: val_acc did not improve from 0.70683
# Epoch 50/100
# Learning rate:  0.001
#  - 48s - loss: 0.2381 - acc: 0.9760 - val_loss: 2.1829 - val_acc: 0.6893
#
# Epoch 00050: val_acc did not improve from 0.70683
# Epoch 51/100
# Learning rate:  0.001
#  - 48s - loss: 0.2354 - acc: 0.9758 - val_loss: 2.3013 - val_acc: 0.6721
#
# Epoch 00051: val_acc did not improve from 0.70683
# Epoch 52/100
# Learning rate:  0.001
#  - 47s - loss: 0.2233 - acc: 0.9785 - val_loss: 2.4078 - val_acc: 0.6540
#
# Epoch 00052: val_acc did not improve from 0.70683
# Epoch 53/100
# Learning rate:  0.001
#  - 47s - loss: 0.2277 - acc: 0.9767 - val_loss: 2.2553 - val_acc: 0.6788
#
# Epoch 00053: val_acc did not improve from 0.70683
# Epoch 54/100
# Learning rate:  0.001
#  - 47s - loss: 0.2239 - acc: 0.9772 - val_loss: 2.3578 - val_acc: 0.6556
#
# Epoch 00054: val_acc did not improve from 0.70683
# Epoch 55/100
# Learning rate:  0.001
#  - 47s - loss: 0.2177 - acc: 0.9788 - val_loss: 3.1032 - val_acc: 0.6095
#
# Epoch 00055: val_acc did not improve from 0.70683
# Epoch 56/100
# Learning rate:  0.001
#  - 47s - loss: 0.2196 - acc: 0.9778 - val_loss: 2.1716 - val_acc: 0.6810
#
# Epoch 00056: val_acc did not improve from 0.70683
# Epoch 57/100
# Learning rate:  0.001
#  - 47s - loss: 0.2142 - acc: 0.9784 - val_loss: 2.2737 - val_acc: 0.6713
#
# Epoch 00057: val_acc did not improve from 0.70683
# Epoch 58/100
# Learning rate:  0.001
#  - 47s - loss: 0.2151 - acc: 0.9781 - val_loss: 2.1432 - val_acc: 0.6994
#
# Epoch 00058: val_acc did not improve from 0.70683
# Epoch 59/100
# Learning rate:  0.001
#  - 47s - loss: 0.2131 - acc: 0.9788 - val_loss: 2.0546 - val_acc: 0.6847
#
# Epoch 00059: val_acc did not improve from 0.70683
# Epoch 60/100
# Learning rate:  0.001
#  - 47s - loss: 0.2108 - acc: 0.9782 - val_loss: 2.1406 - val_acc: 0.6903
#
# Epoch 00060: val_acc did not improve from 0.70683
# Epoch 61/100
# Learning rate:  0.001
#  - 48s - loss: 0.2099 - acc: 0.9783 - val_loss: 2.2773 - val_acc: 0.6691
#
# Epoch 00061: val_acc did not improve from 0.70683
# Epoch 62/100
# Learning rate:  0.001
#  - 47s - loss: 0.2030 - acc: 0.9799 - val_loss: 2.1939 - val_acc: 0.6887
#
# Epoch 00062: val_acc did not improve from 0.70683
# Epoch 63/100
# Learning rate:  0.001
#  - 47s - loss: 0.2012 - acc: 0.9799 - val_loss: 2.1247 - val_acc: 0.6944
#
# Epoch 00063: val_acc did not improve from 0.70683
# Epoch 64/100
# Learning rate:  0.001
#  - 47s - loss: 0.1951 - acc: 0.9806 - val_loss: 2.4022 - val_acc: 0.6742
#
# Epoch 00064: val_acc did not improve from 0.70683
# Epoch 65/100
# Learning rate:  0.001
#  - 47s - loss: 0.1972 - acc: 0.9798 - val_loss: 2.2777 - val_acc: 0.6829
#
# Epoch 00065: val_acc did not improve from 0.70683
# Epoch 66/100
# Learning rate:  0.001
#  - 47s - loss: 0.1963 - acc: 0.9797 - val_loss: 2.9684 - val_acc: 0.6103
#
# Epoch 00066: val_acc did not improve from 0.70683
# Epoch 67/100
# Learning rate:  0.001
#  - 47s - loss: 0.1954 - acc: 0.9792 - val_loss: 3.9660 - val_acc: 0.5397
#
# Epoch 00067: val_acc did not improve from 0.70683
# Epoch 68/100
# Learning rate:  0.001
#  - 48s - loss: 0.1936 - acc: 0.9803 - val_loss: 2.1579 - val_acc: 0.6868
#
# Epoch 00068: val_acc did not improve from 0.70683
# Epoch 69/100
# Learning rate:  0.001
#  - 47s - loss: 0.1840 - acc: 0.9823 - val_loss: 2.7023 - val_acc: 0.6266
#
# Epoch 00069: val_acc did not improve from 0.70683
# Epoch 70/100
# Learning rate:  0.001
#  - 47s - loss: 0.1863 - acc: 0.9812 - val_loss: 2.2857 - val_acc: 0.6667
#
# Epoch 00070: val_acc did not improve from 0.70683
# Epoch 71/100
# Learning rate:  0.001
#  - 47s - loss: 0.1861 - acc: 0.9807 - val_loss: 2.5580 - val_acc: 0.6482
#
# Epoch 00071: val_acc did not improve from 0.70683
# Epoch 72/100
# Learning rate:  0.001
#  - 47s - loss: 0.1878 - acc: 0.9800 - val_loss: 2.2006 - val_acc: 0.6904
#
# Epoch 00072: val_acc did not improve from 0.70683
# Epoch 73/100
# Learning rate:  0.001
#  - 47s - loss: 0.1839 - acc: 0.9806 - val_loss: 2.3403 - val_acc: 0.6667
#
# Epoch 00073: val_acc did not improve from 0.70683
# Epoch 74/100
# Learning rate:  0.001
#  - 47s - loss: 0.1820 - acc: 0.9809 - val_loss: 2.4377 - val_acc: 0.6737
#
# Epoch 00074: val_acc did not improve from 0.70683
# Epoch 75/100
# Learning rate:  0.001
#  - 47s - loss: 0.1802 - acc: 0.9814 - val_loss: 2.4651 - val_acc: 0.6628
#
# Epoch 00075: val_acc did not improve from 0.70683
# Epoch 76/100
# Learning rate:  0.001
#  - 47s - loss: 0.1763 - acc: 0.9823 - val_loss: 2.5100 - val_acc: 0.6607
#
# Epoch 00076: val_acc did not improve from 0.70683
# Epoch 77/100
# Learning rate:  0.001
#  - 47s - loss: 0.1774 - acc: 0.9817 - val_loss: 2.5399 - val_acc: 0.6393
#
# Epoch 00077: val_acc did not improve from 0.70683
# Epoch 78/100
# Learning rate:  0.001
#  - 47s - loss: 0.1776 - acc: 0.9810 - val_loss: 2.3943 - val_acc: 0.6850
#
# Epoch 00078: val_acc did not improve from 0.70683
# Epoch 79/100
# Learning rate:  0.001
#  - 47s - loss: 0.1722 - acc: 0.9828 - val_loss: 4.7759 - val_acc: 0.4821
#
# Epoch 00079: val_acc did not improve from 0.70683
# Epoch 80/100
# Learning rate:  0.001
#  - 47s - loss: 0.1696 - acc: 0.9829 - val_loss: 2.3207 - val_acc: 0.6752
#
# Epoch 00080: val_acc did not improve from 0.70683
# Epoch 81/100
# Learning rate:  0.001
#  - 47s - loss: 0.1704 - acc: 0.9829 - val_loss: 2.2624 - val_acc: 0.7007
#
# Epoch 00081: val_acc did not improve from 0.70683
# Epoch 82/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1393 - acc: 0.9917 - val_loss: 1.9987 - val_acc: 0.7309
#
# Epoch 00082: val_acc improved from 0.70683 to 0.73092, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.082.hg
# Epoch 83/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1241 - acc: 0.9954 - val_loss: 2.0127 - val_acc: 0.7333
#
# Epoch 00083: val_acc improved from 0.73092 to 0.73330, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.083.hg
# Epoch 84/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1185 - acc: 0.9961 - val_loss: 2.0236 - val_acc: 0.7337
#
# Epoch 00084: val_acc improved from 0.73330 to 0.73370, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.084.hg
# Epoch 85/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1147 - acc: 0.9964 - val_loss: 2.0418 - val_acc: 0.7341
#
# Epoch 00085: val_acc improved from 0.73370 to 0.73406, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.085.hg
# Epoch 86/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1116 - acc: 0.9962 - val_loss: 2.2290 - val_acc: 0.7150
#
# Epoch 00086: val_acc did not improve from 0.73406
# Epoch 87/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1082 - acc: 0.9958 - val_loss: 2.0526 - val_acc: 0.7345
#
# Epoch 00087: val_acc improved from 0.73406 to 0.73451, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.087.hg
# Epoch 88/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1043 - acc: 0.9960 - val_loss: 2.0532 - val_acc: 0.7334
#
# Epoch 00088: val_acc did not improve from 0.73451
# Epoch 89/100
# Learning rate:  0.0001
#  - 47s - loss: 0.1010 - acc: 0.9960 - val_loss: 2.0666 - val_acc: 0.7350
#
# Epoch 00089: val_acc improved from 0.73451 to 0.73505, saving model to /content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_6/resnet56v2_1_100_15/checkpoint.089.hg
# Epoch 90/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0973 - acc: 0.9961 - val_loss: 2.1134 - val_acc: 0.7294
#
# Epoch 00090: val_acc did not improve from 0.73505
# Epoch 91/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0940 - acc: 0.9961 - val_loss: 2.0660 - val_acc: 0.7321
#
# Epoch 00091: val_acc did not improve from 0.73505
# Epoch 92/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0905 - acc: 0.9962 - val_loss: 2.0768 - val_acc: 0.7304
#
# Epoch 00092: val_acc did not improve from 0.73505
# Epoch 93/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0878 - acc: 0.9962 - val_loss: 2.0568 - val_acc: 0.7331
#
# Epoch 00093: val_acc did not improve from 0.73505
# Epoch 94/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0850 - acc: 0.9961 - val_loss: 2.0767 - val_acc: 0.7350
#
# Epoch 00094: val_acc did not improve from 0.73505
# Epoch 95/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0823 - acc: 0.9961 - val_loss: 2.0697 - val_acc: 0.7327
#
# Epoch 00095: val_acc did not improve from 0.73505
# Epoch 96/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0797 - acc: 0.9964 - val_loss: 2.0723 - val_acc: 0.7296
#
# Epoch 00096: val_acc did not improve from 0.73505
# Epoch 97/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0772 - acc: 0.9967 - val_loss: 2.0326 - val_acc: 0.7329
#
# Epoch 00097: val_acc did not improve from 0.73505
# Epoch 98/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0751 - acc: 0.9966 - val_loss: 2.2931 - val_acc: 0.7078
#
# Epoch 00098: val_acc did not improve from 0.73505
# Epoch 99/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0729 - acc: 0.9965 - val_loss: 2.1201 - val_acc: 0.7339
#
# Epoch 00099: val_acc did not improve from 0.73505
# Epoch 100/100
# Learning rate:  0.0001
#  - 47s - loss: 0.0708 - acc: 0.9967 - val_loss: 2.0645 - val_acc: 0.7316
#
# Epoch 00100: val_acc did not improve from 0.73505
# Model:  resnet56v2_1_100_15 , Loss:  2.0736314897580765 , Accuracy:  0.7326479997167323
# Done!

# %%
print('=====output=====')
# !ls '/content/drive/My Drive/PUBLIC/PROJECT/OCR/STR/COLAB_OUTPUT_2/resnet56v2'
# Out:
# =====output=====
# accuracy.png	   checkpoint.002.hg  csv_eva.csv  loss.png  weights.h5
# checkpoint.001.hg  checkpoint.006.hg  csv_fit.csv  model.h5
